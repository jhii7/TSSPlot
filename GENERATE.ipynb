# %%
# %pylab inline
import seaborn as sns
import scipy.stats
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Generate dataframe
df = pd.read_csv("~/lab5/annotations/tss_histogram.txt", sep="\t")
df.columns = ["Distance from Center", "Oct4 Coverage", "Oct4 tags", "Oct4 -tags", "Sox2 Coverage", "Sox2 tags", "Sox2 -tags", "Klf4 Coverage", "Klf4 tags", "Klf4 -tags", "H3K4me2 Coverage", "H3K4me2 tags", "H3K4me2 -tags", "H3K27ac Coverage", "H3K27ac tags", "H3K27ac -tags"]
df
# Out:
#      Distance from Center  Oct4 Coverage  Oct4 tags  Oct4 -tags  \
# 0                   -4000       0.894853   0.003720    0.003860
# 1                   -3990       0.890395   0.003763    0.004073
# 2                   -3980       0.881561   0.003811    0.003769
# 3                   -3970       0.888774   0.004097    0.003751
# 4                   -3960       0.882209   0.003720    0.003787
# ..                    ...            ...        ...         ...
# 796                  3960       0.856193   0.003495    0.003665
# 797                  3970       0.859678   0.003629    0.003878
# 798                  3980       0.849952   0.003368    0.003769
# 799                  3990       0.845008   0.003477    0.003975
# 800                  4000       0.845170   0.003592    0.003957
#
#      Sox2 Coverage  Sox2 tags  Sox2 -tags  Klf4 Coverage  Klf4 tags  \
# 0         0.816687   0.003323    0.003360       0.929456   0.004223
# ...

# %%
df.plot('Distance from Center', y = ['Oct4 Coverage', 'Sox2 Coverage', 'Klf4 Coverage', 'H3K4me2 Coverage', 'H3K27ac Coverage'])
plt.ylabel("Relative read count")
plt.title("Composite Plot")
plt.savefig('CompositePlot.jpg')
plt.show()
